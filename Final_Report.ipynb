# %% [markdown]
# <a href="https://colab.research.google.com/github/Tebbyrain/ai-gen-12-14/blob/main/Final_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 專題報告

# %% [markdown]
# * 學號：N12345678
# * 姓名：許智超
# * 信箱：<cchsu@mail.nsysu.edu.tw>

# %% [markdown]
# ## 前言

# %% [markdown]
# 寫下您程式的目的是什麼？
# 為什麼您會選擇寫這支程式？

# %% [markdown]
# ## 方法

# %% [markdown]
# 簡單說明您程式的架構或流程
# 您有import什麼模組嗎？
# 您有資料做什麼處理嗎？

# %% [markdown]
# ## 結果

# %% [markdown]
# 展示您的程示碼，並說明是否需要輸入什麼資料，以及會輸出什麼結果。

# %%
# 請在這裡撰寫您的程式碼
print("這是我的程式碼")
# Out:
# 這是我的程式碼

# %% [markdown]
# ## 結論

# %% [markdown]
# 您的程式是否達成它的目的？
# 您的程式有沒有什麼問題？
# 您的程式可以運用在什麼地方？
# 您的程式將來如何進一步發展？
